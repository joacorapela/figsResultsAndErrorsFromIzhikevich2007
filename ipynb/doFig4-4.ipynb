# %% [markdown]
# ## Import requirements

# %%
import sys
import numpy as np
import pdb
import matplotlib.pyplot as plt
sys.path.append("../src/models")
sys.path.append("../src/utils")
import INapIKModel
from plotFunctions import plotLowThresholdINapIKVectorField

# %% [markdown]
# ## Plot model nullclines and vector field

# %%
# %matplotlib notebook

figFilename = 'figures/fig4-4.eps'

plotLowThresholdINapIKVectorField()                               
plt.savefig(figFilename)
# Out:
# ../src/utils/plotFunctions.py:79: RuntimeWarning: divide by zero encountered in true_divide
#   vNullcline = (i-iLsDense-iNapsDense)/(gK*(vsDense-eK))
# <img src="data:image/png;base64,..." width="640">
# ../src/utils/plotFunctions.py:104: RuntimeWarning: divide by zero encountered in true_divide
#   vNullcline = (i-iLsDense-iNapsDense)/(gK*(vsDense-eK))
